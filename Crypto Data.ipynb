# %% [markdown]
# # Cryptocurrency Market Data Analysis

# %% [markdown]
# ##### Project: Crypto Market Report
#
# In this project I will be sorting fictious data of a cryptocurrency market using Pandas, Matplotlib and Seaborn. Hope you enjoy.

# %%
import pandas as pd

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # Reading The .CSV File of Crypto data

# %%
# Let's start importing the .csv file and create
# our dataset named crypto_info
crypto_info = pd.read_csv("consolidated_coin_data.csv")
crypto_info
# Out:
#          Currency          Date  Open  High   Low Close      Volume  \
# 0           tezos  Dec 04, 2019  1.29  1.32  1.25  1.25  46,048,752
# 1           tezos  Dec 03, 2019  1.24  1.32  1.21  1.29  41,462,224
# 2           tezos  Dec 02, 2019  1.25  1.26  1.20  1.24  27,574,097
# 3           tezos  Dec 01, 2019  1.33  1.34  1.25  1.25  24,127,567
# 4           tezos  Nov 30, 2019  1.31  1.37  1.31  1.33  28,706,667
# ...           ...           ...   ...   ...   ...   ...         ...
# 28939  bitcoin-sv  May 02, 2013  3.78  4.04  3.01  3.37           0
# 28940  bitcoin-sv  May 01, 2013  4.29  4.36  3.52  3.80           0
# 28941  bitcoin-sv  Apr 30, 2013  4.40  4.57  4.17  4.30           0
# 28942  bitcoin-sv  Apr 29, 2013  4.37  4.57  4.23  4.38           0
# 28943  bitcoin-sv  Apr 28, 2013  4.30  4.40  4.18  4.35           0
#
#         Market Cap
# 0      824,588,509
# 1      853,213,342
# 2      817,872,179
# 3      828,296,390
# 4      879,181,680
# ...            ...
# ...

# %%
# Reading only the first 25 crypto currencies on the .csv
crypto_info.head(25)
# Out:
#    Currency          Date  Open  High   Low Close       Volume   Market Cap
# 0     tezos  Dec 04, 2019  1.29  1.32  1.25  1.25   46,048,752  824,588,509
# 1     tezos  Dec 03, 2019  1.24  1.32  1.21  1.29   41,462,224  853,213,342
# 2     tezos  Dec 02, 2019  1.25  1.26  1.20  1.24   27,574,097  817,872,179
# 3     tezos  Dec 01, 2019  1.33  1.34  1.25  1.25   24,127,567  828,296,390
# 4     tezos  Nov 30, 2019  1.31  1.37  1.31  1.33   28,706,667  879,181,680
# 5     tezos  Nov 29, 2019  1.28  1.34  1.28  1.31   32,270,224  867,085,098
# 6     tezos  Nov 28, 2019  1.26  1.35  1.22  1.28   44,240,281  845,073,679
# 7     tezos  Nov 27, 2019  1.24  1.27  1.16  1.26   47,723,271  829,672,736
# 8     tezos  Nov 26, 2019  1.24  1.28  1.23  1.24   54,828,808  822,065,277
# 9     tezos  Nov 25, 2019  1.33  1.33  1.21  1.24   64,954,006  815,688,075
# 10    tezos  Nov 24, 2019  1.40  1.42  1.31  1.34   49,206,070  887,731,654
# ...

# %%
# Reading only the last 50 crypto currencies on the .csv
crypto_info.tail(30)
# Out:
#          Currency          Date  Open  High   Low Close Volume  Market Cap
# 28914  bitcoin-sv  May 27, 2013  3.23  3.26  3.02  3.10      0  55,882,132
# 28915  bitcoin-sv  May 26, 2013  3.12  3.33  3.09  3.25      0  58,457,958
# 28916  bitcoin-sv  May 25, 2013  3.19  3.20  3.05  3.12      0  56,026,343
# 28917  bitcoin-sv  May 24, 2013  3.17  3.19  3.04  3.18      0  57,017,469
# 28918  bitcoin-sv  May 23, 2013  3.12  3.19  3.09  3.18      0  56,949,220
# 28919  bitcoin-sv  May 22, 2013  3.09  3.14  3.03  3.12      0  55,766,901
# 28920  bitcoin-sv  May 21, 2013  3.19  3.22  3.04  3.09      0  55,073,034
# 28921  bitcoin-sv  May 20, 2013  3.31  3.32  3.15  3.18      0  56,682,749
# 28922  bitcoin-sv  May 19, 2013  3.30  3.41  3.19  3.30      0  58,760,676
# 28923  bitcoin-sv  May 18, 2013  3.20  3.36  3.13  3.29      0  58,518,794
# 28924  bitcoin-sv  May 17, 2013  2.89  3.34  2.87  3.19      0  56,498,074
# ...

# %%
# Sorting data by Currency name
crypto_info.sort_values('Currency')
# Out:
#            Currency          Date      Open      High       Low     Close  \
# 3617   binance-coin  Aug 16, 2016      3.59      3.65      3.58      3.64
# 3217   binance-coin  Sep 20, 2017  0.815032  0.816384  0.743676  0.747890
# 3216   binance-coin  Sep 21, 2017  0.764013  0.781775  0.684281  0.702140
# 3215   binance-coin  Sep 22, 2017  0.698871  0.740154  0.683260  0.715893
# 3214   binance-coin  Sep 23, 2017  0.717196  0.777400  0.707845  0.770965
# ...             ...           ...       ...       ...       ...       ...
# 12865           xrp  Sep 20, 2017  0.183710  0.186229  0.180333  0.182078
# 12866           xrp  Sep 19, 2017  0.189819  0.190680  0.181334  0.184041
# 12867           xrp  Sep 18, 2017  0.178309  0.190019  0.178309  0.189768
# 12869           xrp  Sep 16, 2017  0.181925  0.187417  0.172279  0.179082
# 14471           xrp  Apr 28, 2013    135.30    135.98    132.10    134.21
#
#            Volume     Market Cap
# 3617    2,302,180    171,483,591
# ...
